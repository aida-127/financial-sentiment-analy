# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8')
# %matplotlib inline

# %%
# Cell 2: Load the data
# Using your actual data file: data\raw_analyst_ratings.csv
try:
    df = pd.read_csv('data/raw_analyst_ratings.csv')
    print("✅ Data loaded successfully!")
    print(f"Dataset shape: {df.shape}")
    print("\n📊 Dataset info:")
    print(df.info())
    print("\n👀 First 5 rows:")
    print(df.head())
except FileNotFoundError:
    print("❌ Data file not found. Please ensure 'data/raw_analyst_ratings.csv' exists")
    # Create sample structure for demonstration
    print("Creating sample data structure for demonstration...")
    data = {
        'headline': ['Apple stock hits all-time high', 'Tesla faces production challenges', 'Microsoft earnings beat expectations'],
        'publisher': ['CNBC', 'Bloomberg', 'Reuters'], 
        'date': ['2024-01-15 09:30:00', '2024-01-15 14:45:00', '2024-01-16 10:15:00'],
        'stock': ['AAPL', 'TSLA', 'MSFT']
    }
    df = pd.DataFrame(data)
    print("Sample data created for testing purposes")
# Out:
# ❌ Data file not found. Please ensure 'data/raw_analyst_ratings.csv' exists
# Creating sample data structure for demonstration...
# Sample data created for testing purposes
